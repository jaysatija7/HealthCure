# %%
from tensorflow.keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout,Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %%
train_dir = '../data/pneumonia/train/'
val_dir = '../data/pneumonia/val/'
test_dir = '../data/pneumonia/test/'

# %%
batch_size = 16
epochs = 20
img_height,img_width = 150,150
nb_train_samples = 5217
nb_validation_samples = 17

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(img_height,img_width),
                                               batch_size=batch_size,
                                               class_mode='binary')

val_data = test_datagen.flow_from_directory(val_dir,
                                               target_size=(img_height,img_width),
                                               batch_size=batch_size,
                                               class_mode='binary')

test_data = test_datagen.flow_from_directory(test_dir,
                                               target_size=(img_height,img_width),
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width,img_height,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  activation_1 (Activation)   (None, 72, 72, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  activation_2 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_4 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              metrics=['accuracy'],
              optimizer='rmsprop')

# %%
mc = ModelCheckpoint(
    'pnemonia_model_mc.h5',
    monitor="val_loss",
    verbose=1,
    save_best_only=False,
)

# %%
history = model.fit(train_data,
                  epochs=epochs,
                  steps_per_epoch = nb_train_samples//batch_size,
                  validation_data=val_data,
                  validation_steps=nb_validation_samples//batch_size,
                 )
model.save('../models/pneumonia_model.h5')
# Out:
# Epoch 1/20
# 326/326 [==============================] - 194s 592ms/step - loss: 0.5906 - accuracy: 0.7698 - val_loss: 0.5312 - val_accuracy: 0.8125
# Epoch 2/20
# 326/326 [==============================] - 182s 556ms/step - loss: 0.2838 - accuracy: 0.8842 - val_loss: 0.6688 - val_accuracy: 0.7500
# Epoch 3/20
# 326/326 [==============================] - 178s 546ms/step - loss: 0.2463 - accuracy: 0.9043 - val_loss: 0.5631 - val_accuracy: 0.7500
# Epoch 4/20
# 326/326 [==============================] - 181s 555ms/step - loss: 0.2201 - accuracy: 0.9206 - val_loss: 0.9203 - val_accuracy: 0.6875
# Epoch 5/20
# 326/326 [==============================] - 178s 546ms/step - loss: 0.2022 - accuracy: 0.9305 - val_loss: 0.8253 - val_accuracy: 0.7500
# Epoch 6/20
# 326/326 [==============================] - 176s 540ms/step - loss: 0.1952 - accuracy: 0.9290 - val_loss: 1.6704 - val_accuracy: 0.6250
# Epoch 7/20
# 326/326 [==============================] - 163s 500ms/step - loss: 0.2163 - accuracy: 0.9178 - val_loss: 0.4064 - val_accuracy: 0.9375
# Epoch 8/20
# 326/326 [==============================] - 123s 377ms/step - loss: 0.1954 - accuracy: 0.9310 - val_loss: 0.5745 - val_accuracy: 0.8125
# Epoch 9/20
# 326/326 [==============================] - 123s 378ms/step - loss: 0.1956 - accuracy: 0.9382 - val_loss: 1.1769 - val_accuracy: 0.6250
# Epoch 10/20
# 326/326 [==============================] - 124s 380ms/step - loss: 0.2152 - accuracy: 0.9270 - val_loss: 0.9426 - val_accuracy: 0.6875
# Epoch 11/20
# 326/326 [==============================] - 124s 380ms/step - loss: 0.2222 - accuracy: 0.9244 - val_loss: 2.6731 - val_accuracy: 0.6250
# Epoch 12/20
# 326/326 [==============================] - 125s 385ms/step - loss: 0.1788 - accuracy: 0.9387 - val_loss: 0.9221 - val_accuracy: 0.7500
# Epoch 13/20
# 326/326 [==============================] - 124s 379ms/step - loss: 0.1854 - accuracy: 0.9381 - val_loss: 1.1400 - val_accuracy: 0.7500
# Epoch 14/20
# 326/326 [==============================] - 124s 380ms/step - loss: 0.2023 - accuracy: 0.9345 - val_loss: 0.5247 - val_accuracy: 0.8125
# Epoch 15/20
# 326/326 [==============================] - 124s 380ms/step - loss: 0.1731 - accuracy: 0.9413 - val_loss: 2.0613 - val_accuracy: 0.5625
# Epoch 16/20
# 326/326 [==============================] - 124s 379ms/step - loss: 0.2014 - accuracy: 0.9388 - val_loss: 0.5367 - val_accuracy: 0.8125
# Epoch 17/20
# 326/326 [==============================] - 128s 393ms/step - loss: 0.2030 - accuracy: 0.9368 - val_loss: 0.5829 - val_accuracy: 0.8125
# Epoch 18/20
# 326/326 [==============================] - 126s 386ms/step - loss: 0.2067 - accuracy: 0.9394 - val_loss: 0.5967 - val_accuracy: 0.8125
# Epoch 19/20
# 326/326 [==============================] - 125s 384ms/step - loss: 0.1723 - accuracy: 0.9484 - val_loss: 0.8269 - val_accuracy: 0.8125
# Epoch 20/20
# 326/326 [==============================] - 125s 384ms/step - loss: 0.1893 - accuracy: 0.9342 - val_loss: 0.6854 - val_accuracy: 0.6250

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
scores = model.evaluate_generator(test_data)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
#
# accuracy: 83.17%
